# %% [markdown]
# # Example running
#
#
# If you're not familiar with running code in bash, here's a good example of how to run code in jupyter. However, if you want to set params to let this project running more formatted and easy to use, you may want to still run it in bash.

# %% [markdown]
# Please make sure you know how to run jupyter notebook.
# First of all, you better choose python==3.10 to run this code, because that's the version I used lol.
# After installation, you need to install the required packages.
#
# ## Installation and environment
# This line of code below will run in bash to install the required packages. Or, you can run it directly in bash. Then you should set your environment variables to call LLMs.

# %%
# %pip install -r requirements.txt

# %%
from utils import set_env
set_env()

# %% [markdown]
# ## Import LangGraph from other script

# %%
from MainGraph import main_graph

# %% [markdown]
# ## See how the Graph work
# run the code below you can see the shape of Lang Graph. Data will send to different node to process, finally generate the story you want.

# %%
from IPython.display import Image, display
display(Image(main_graph.get_graph(xray=1).draw_mermaid_png()))

# %% [markdown]
# ## Set basic information of your story
# - **Language**: English, Chinese, Japanese, Korean, etc.
# - **Topic**: for example, love-fiction in high school, adventure in the forest, etc. change to any topic you like.
# - **MainCharacter**: for example, Allen and Mika, John and Mary, etc.
# - **MainGoal**: for example, Allen and Mika get in love, John and Mary meet each other, etc.

# %%
initial_state = {
            "Language": "English",
            "Topic": "love-fiction in high-school and families",
            "MainCharacter": 'Ellen and Mika, two high school friends who grow up with each other',
            "MainGoal": "Mika wants to find the meaning of love and get in love with Ellen forever"
}

# %% [markdown]
# ## Run this line
# Then you can run this line to generate the story.
# May take a while, but you will see how this story is generated, the process will be printed in the console below.
# Using different LLMs may lead to different running time and different results. In general, the original setting of models won't lead to fails.

# %%
result = main_graph.invoke(initial_state,config={"recursion_limit": 100})
# Out:
# Setting up StoryStarterBeginning...
# Generating memory...
# Writing settings to your story setting path...
# Writing long-term memories to your story memory path...
# Setting up TwistWritingAssistant...
# Start to catch KG nodes in generated outline...
# Generating key twist nodes in generated outline...
# Outline in generated twist outline: Ellen and Mika had been best friends since childho ...(etc.)
# Reader is reading...
# Editing story with reviewing...
# Reader is reading...
# Editing story with reviewing...
# Saving story at your storage path...
# 0.8154046
# Generating memory...
# Pulling memory...
# Writing long-term memories to your story memory path...
# One generate round is finished. Now start to generate next round.
# Setting up TwistWritingAssistant...
# Start to catch KG nodes in generated outline...
# Generating key twist nodes in generated outline...
# Outline in generated twist outline: Ellen and Mika had been best friends since childho ...(etc.)
# Reader is reading...
# Editing story with reviewing...
# Saving story at your storage path...
# 0.83908916
# Generating memory...
# Pulling memory...
# Writing long-term memories to your story memory path...
# One generate round is finished. Now start to generate next round.
# Setting up TwistWritingAssistant...
# Start to catch KG nodes in generated outline...
# Generating key twist nodes in generated outline...
# Outline in generated twist outline: Ellen and Mika had been best friends since they we ...(etc.)
# Reader is reading...
# Editing story with reviewing...
# Saving story at your storage path...
# 0.81013954
# Generating memory...
# Pulling memory...
# Writing long-term memories to your story memory path...
# One generate round is finished. Now start to generate next round.
# Setting up TwistWritingAssistant...
# Start to catch KG nodes in generated outline...
# Generating key twist nodes in generated outline...
# Outline in generated twist outline: In the halls of Valley High School, Ellen couldn't ...(etc.)
# Reader is reading...
# Editing story with reviewing...
# Saving story at your storage path...
# 0.8270037
# Generating memory...
# Pulling memory...
# Writing long-term memories to your story memory path...
# One generate round is finished. Now start to generate next round.
# Setting up TwistWritingAssistant...
# Start to catch KG nodes in generated outline...
# Generating key twist nodes in generated outline...
# Outline in generated twist outline: High school had always been a place of drama, roma ...(etc.)
# Reader is reading...
# Editing story with reviewing...
# Saving story at your storage path...
# 0.7567507
# Generating memory...
# Pulling memory...
# Writing long-term memories to your story memory path...
# End Generation doesn't work, try again...
# Finally! The story's generation is finished.
# Saved your story to file: result.json

# %% [markdown]
# If your process failed, please try again or change the params, especially the LLMs. If your process finished, you can see the result length below, and your answer will be saved in `result.json`.

# %%
print(f"Total Length of Story: {result['TotalStoryLength']}")
# Out:
# Total Length of Story: 25352

# %%
print(f"The shape of output be like:")
for k,v in result.items():
    print(f"{k}: Type:{type(v)}, \nvalue: {v}\n")
# Out:
# The shape of output be like:
# MainCharacter: Type:<class 'str'>,
# value: Ellen and Mika, two high school friends who grow up with each other
#
# MainGoal: Type:<class 'str'>,
# value: Mika wants to find the meaning of love and get in love with Ellen forever
#
# StartSign: Type:<class 'bool'>,
# value: False
#
# RecentStory: Type:<class 'list'>,
# value: ["1. Introduction to the group of friends: Ellen, Alex, Mika, Liam, and Rebecca\n   a. Autumn setting at the high school\n   b. Excitement and anticipation for the new school year\n2. Ellen's growing feelings for Alex\n   a. Confiding in Mika for advice and support\n   b. Navigating the balance between love and friendship\n3. Mika's emotional journey\n   a. Feeling lonely as Ellen's attention is divided\n   b. Questioning her own place in the world\n4. Introduction of Nora, the new student\n   a. Vibrant personality and unique perspective\n   b. Quickly captures the attention of the entire school\n5. Nora's impact on the group dynamic\n   a. Ellen and Mika drawn to her free-spirited nature\n   b. Nora forms a close bond with Mika\n   c. Encourages Mika to explore new passions and step outside her comfort zone\n6. Alex's fascination with Nora\n   a. Captivated by her confidence and independence\n   b. Reevaluates his own priorities and aspirations\n7. The group's journey through high school\n   a. Facing trials and triumphs together\n   b. Celebrating victories and commiserating over failures\n   c. The enduring bond between Ellen and Mika\n8. Personal growth and self-discovery\n   a. Mika discovers a passion for photography\n   b. Ellen learns the importance of open communication and honesty in relationships\n9. Graduation and the future\n   a. Nora's profound impact on their lives\n   b. The group stands on the precipice of adulthood\n   c. Ready to face challenges and embrace new adventures\n10. The lasting power of love and friendship\n    a. The group's emotional farewell\n    b. Mika and Ellen's heartfelt moment\n    c. Setting off into the unknown, guided by the strength of their bond"]
#
# Language: Type:<class 'str'>,
# value: English
#
# Topic: Type:<class 'str'>,
# value: love-fiction in high-school and families
#
# similarity: Type:<class 'numpy.float32'>,
# value: 0.7567507028579712
#
# TotalStoryLength: Type:<class 'int'>,
# value: 25352
